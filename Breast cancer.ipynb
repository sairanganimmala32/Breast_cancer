# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot
# %matplotlib inline

# %%
data=pd.read_csv('data.csv')
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         1        17.99         10.38          122.80     1001.0
# 1    842517         1        20.57         17.77          132.90     1326.0
# 2  84300903         1        19.69         21.25          130.00     1203.0
# 3  84348301         1        11.42         20.38           77.58      386.1
# 4  84358402         1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
data.drop('Unnamed: 32',axis=1,inplace=True)

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         1        17.99         10.38          122.80     1001.0
# 1    842517         1        20.57         17.77          132.90     1326.0
# 2  84300903         1        19.69         21.25          130.00     1203.0
# 3  84348301         1        11.42         20.38           77.58      386.1
# 4  84358402         1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
data.isnull().sum()
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
data['diagnosis']=np.where(data['diagnosis']=='M','1','0')

# %%
data['diagnosis'].value_counts()/569
# Out:
# diagnosis
# 0    0.627417
# 1    0.372583
# Name: count, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
sns.barplot(data['diagnosis'])
# Out:
# <Axes: ylabel='diagnosis'>

# %%
num_col=[col for col in data.columns if data[col].dtype!="O" and col not in ('id')]
num_col
# Out:
# ['radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst']

# %%
for col in num_col:
    plt.boxplot(data[col])
    plt.xlabel(col)
    plt.title(col)
    plt.show()

# %%
for col in num_col:
    data.groupby('diagnosis')[col].median().plot.bar()
    plt.xlabel(col)
    plt.show()

# %%
data[num_col].head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  \
# ...

# %%
X=data.drop('diagnosis',axis=1)
y=data['diagnosis']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import RobustScaler
scaler=RobustScaler()

# %%
X_train_scaled=scaler.fit_transform(X_train)

# %%
X_train_scaled
# Out:
# array([[ 7.78179438e-04, -4.48000000e-01, -7.43036837e-01, ...,
#         -2.55730360e-01,  1.86723465e-01,  5.75036783e-01],
#        [-1.61645117e-03, -6.94153846e-01, -2.06648697e-02, ...,
#         -3.49812461e-01, -8.47000355e-01, -8.11672388e-02],
#        [ 9.82304645e-01, -2.60923077e-01, -1.41060198e-01, ...,
#         -1.74463430e-01,  4.30954917e-01,  6.10593428e-02],
#        ...,
#        [ 1.13279166e+02, -9.53600000e-01, -7.27762803e-02, ...,
#         -5.03594499e-01, -5.04792332e-01,  6.30210888e-02],
#        [-3.82608561e-03, -8.83692308e-01, -9.07457323e-02, ...,
#         -1.02995416e+00, -1.27866525e+00, -7.10397254e-01],
#        [ 2.49046365e-03, -4.43076923e-01,  9.35309973e-01, ...,
#         -2.42237966e-02, -9.90415335e-01,  3.55321236e-01]])

# %%
X_train_final=pd.DataFrame(X_train_scaled,columns=X_train.columns)

# %%
X_train_final
# Out:
#                id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    7.781794e-04    -0.448000     -0.743037       -0.416595  -0.400111
# 1   -1.616451e-03    -0.694154     -0.020665       -0.661066  -0.596892
# 2    9.823046e-01    -0.260923     -0.141060       -0.269844  -0.245697
# 3   -3.937083e-03     1.230769     -0.026056        1.112978   1.372866
# 4   -5.383703e-03    -1.557908     -0.951482       -1.452083  -1.128702
# 5   -5.441719e-03    -0.867200      0.218329       -0.823933  -0.707825
# 6    9.570911e-01    -0.056615     -0.541779       -0.017487  -0.079298
# 7   -1.029932e-01    -0.531692     -1.014376       -0.523573  -0.464219
# 8   -6.048682e-03     0.440615      0.592093        0.381279   0.458087
# 9   -6.556730e-03     1.309538      1.147350        1.325561   1.503867
# 10   1.145194e+01    -0.403692      0.232704       -0.374764  -0.368615
# 11  -6.084171e-03     0.044308      0.642408        0.026402   0.034980
# ...

# %%
X_train_final.isnull().sum()
# Out:
# id                         0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
X_test_scaled=scaler.transform(X_test)

# %%
X_test_scaled
# Out:
# array([[ 1.28232544e-03,  2.21538462e-02,  3.22551662e-01, ...,
#          1.10694936e+00,  1.10117146e+00,  1.51177048e+00],
#        [ 1.03281539e+00, -2.46153846e-02,  1.17250674e+00, ...,
#         -4.04302980e-01, -5.18991835e-01, -5.98087298e-01],
#        [ 4.91875853e-04,  1.74769231e-01, -5.50763702e-01, ...,
#         -1.73942488e-01, -9.56336528e-01, -6.36341344e-01],
#        ...,
#        [ 1.55981969e-03,  9.84615385e-02, -8.08625337e-03, ...,
#          3.07824547e-01,  5.60880369e-02,  5.01961746e-01],
#        [-5.61343800e-04, -2.46153846e-03,  5.11230907e-01, ...,
#         -4.45040633e-01, -2.44941427e-01, -6.61844041e-01],
#        [ 2.37103416e-03, -9.78953846e-01,  5.77717880e-01, ...,
#         -7.62815170e-01, -5.31771388e-01, -3.01373222e-01]])

# %%
X_test_final=pd.DataFrame(X_test_scaled,columns=X_train.columns)

# %%
X_test_final.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  0.001282     0.022154      0.322552        0.085719   0.022995
# 1  1.032815    -0.024615      1.172507       -0.069947  -0.029406
# 2  0.000492     0.174769     -0.550764        0.118292   0.161801
# 3 -0.001672     0.233846     -0.099730        0.174181   0.235942
# 4 -0.006363    -0.068923     -0.054807       -0.121035  -0.068706
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0         0.780547          0.853418        0.831893             0.881013
# 1        -0.435423         -0.677779       -0.355016            -0.242854
# 2        -0.877546         -0.617080       -0.424637            -0.135328
# 3        -1.622454         -0.675357       -0.385202            -0.370633
# 4        -0.332529         -0.910082       -0.376359            -0.085432
#
#    symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  \
# ...

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
lr.fit(X_train_final,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test_final)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
print('Accuracy:',accuracy_score(y_test,y_pred))
print('Confusion matrix:',confusion_matrix(y_test,y_pred))
print('Classification_report:',classification_report(y_test,y_pred))
# Out:
# Accuracy: 0.9590643274853801
# Confusion matrix: [[103   5]
#  [  2  61]]
# Classification_report:               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.97       108
#            1       0.92      0.97      0.95        63
#
#     accuracy                           0.96       171
#    macro avg       0.95      0.96      0.96       171
# weighted avg       0.96      0.96      0.96       171
